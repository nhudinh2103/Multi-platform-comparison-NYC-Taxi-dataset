# %% [markdown]
# # What's in this exercise?
# We run the common functions notebook so we can reuse capability defined there, and then...<BR>
# 1) Load yellow taxi data in staging directory to raw data directory, and save as parquet<BR>
# 2) Create external unmanaged Hive tables<BR>
# 3) Create statistics for tables

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType,LongType,FloatType,DoubleType, TimestampType

# %%
# Define source and destination directories
srcDataDirRoot = f"gs://nyctaxi-raw/transactional-data/" #Root dir for source data
destDataDirRoot = f"gs://nyctaxi-silver/nyctaxi/transactions/yellow-taxi/" #Root dir for consumable data

#Canonical ordered column list for yellow taxi across years to homogenize schema
canonicalTripSchemaColList = ["taxi_type","vendor_id","pickup_datetime","dropoff_datetime","store_and_fwd_flag","rate_code_id","pickup_location_id","dropoff_location_id","pickup_longitude","pickup_latitude","dropoff_longitude","dropoff_latitude","passenger_count","trip_distance","fare_amount","extra","mta_tax","tip_amount","tolls_amount","improvement_surcharge","total_amount","payment_type","trip_year","trip_month"]

# %% [markdown]
# ### 1.  Execute notebook with common/reusable functions

# %%
# %run "../../../../01-General/2-CommonFunctions.ipynb"
# Out:
# Code from file 'file:///home/dinhnn/git/personal/Databricks-NYC-Taxi/Workspace/01-General/2-CommonFunctions.ipynb':
#  import os
# import math
# import glob
# import re
# prqShrinkageFactor = 0.19 #We found a saving in space of 81% with Parquet
# def analyzeTables(databaseAndTable):
#   try:
#     print("Table: " + databaseAndTable)
#     print("....refresh table")
#     sql("REFRESH TABLE " + databaseAndTable)
#     print("....analyze table")
#     sql("ANALYZE TABLE " + databaseAndTable + " COMPUTE STATISTICS")
#     print("....done")
#   except Exception as e:
#     return e
# def calcOutputFileCountTxtToPrq(srcDataFile, targetedFileSizeMB):
#   try:
#     estFileCount = int(math.floor((os.path.getsize(srcDataFile) * prqShrinkageFactor) / (targetedFileSizeMB * 1024 * 1024)))
#     if(estFileCount == 0):
#       return 1
#     else:
#       return estFileCount
#   except Exception as e:
#     return e
# #Delete residual files from job operation (_SUCCESS, _start*, _committed*)
# #Should be called with '/dbfs/mnt/...'
# def recursivelyDeleteSparkJobFlagFiles(directoryPath):
#   try:
#     files = glob.glob(directoryPath + '/**/*', recursive=True)
#     for file in files:
#       if not os.path.basename(file).endswith('parquet') and os.path.isfile(file):
#         fileReplaced = re.sub('/dbfs', 'dbfs:',file)
#         print("Deleting...." +  fileReplaced)
#         dbutils.fs.rm(fileReplaced)
#   except Exception as e:
#     return e

# %% [markdown]
# #### 2. Define schema for source data
# Different years have different schemas - fields added/removed

# %%
#Schema for data based on year and month

# 2017
yellowTripSchema2017H1 = StructType([
    StructField("vendor_id", StringType(), True),
    StructField("pickup_datetime", TimestampType(), True),
    StructField("dropoff_datetime", TimestampType(), True),
    StructField("passenger_count", IntegerType(), True),
    StructField("trip_distance", DoubleType(), True),
    StructField("rate_code_id", IntegerType(), True),
    StructField("store_and_fwd_flag", StringType(), True),
    StructField("pickup_location_id", IntegerType(), True),
    StructField("dropoff_location_id", IntegerType(), True),
    StructField("payment_type", StringType(), True),
    StructField("fare_amount", DoubleType(), True),
    StructField("extra", DoubleType(), True),
    StructField("mta_tax", DoubleType(), True),
    StructField("tip_amount", DoubleType(), True),
    StructField("tolls_amount", DoubleType(), True),
    StructField("improvement_surcharge", DoubleType(), True),
    StructField("total_amount", DoubleType(), True)])

#Second half of 2016
yellowTripSchema2016H2 = StructType([
    StructField("vendor_id", StringType(), True),
    StructField("pickup_datetime", TimestampType(), True),
    StructField("dropoff_datetime", TimestampType(), True),
    StructField("passenger_count", IntegerType(), True),
    StructField("trip_distance", DoubleType(), True),
    StructField("rate_code_id", IntegerType(), True),
    StructField("store_and_fwd_flag", StringType(), True),
    StructField("pickup_location_id", IntegerType(), True),
    StructField("dropoff_location_id", IntegerType(), True),
    StructField("payment_type", StringType(), True),
    StructField("fare_amount", DoubleType(), True),
    StructField("extra", DoubleType(), True),
    StructField("mta_tax", DoubleType(), True),
    StructField("tip_amount", DoubleType(), True),
    StructField("tolls_amount", DoubleType(), True),
    StructField("improvement_surcharge", DoubleType(), True),
    StructField("total_amount", DoubleType(), True),
    StructField("junk1", StringType(), True),
    StructField("junk2", StringType(), True)])

# 2015 and 2016 first half of the year
yellowTripSchema20152016H1 = StructType([
    StructField("vendor_id", StringType(), True),
    StructField("pickup_datetime", TimestampType(), True),
    StructField("dropoff_datetime", TimestampType(), True),
    StructField("passenger_count", IntegerType(), True),
    StructField("trip_distance", DoubleType(), True),
    StructField("pickup_longitude", DoubleType(), True),
    StructField("pickup_latitude", DoubleType(), True),
    StructField("rate_code_id", IntegerType(), True),
    StructField("store_and_fwd_flag", StringType(), True),
    StructField("dropoff_longitude", DoubleType(), True),
    StructField("dropoff_latitude", DoubleType(), True),
    StructField("payment_type", StringType(), True),
    StructField("fare_amount", DoubleType(), True),
    StructField("extra", DoubleType(), True),
    StructField("mta_tax", DoubleType(), True),
    StructField("tip_amount", DoubleType(), True),
    StructField("tolls_amount", DoubleType(), True),
    StructField("improvement_surcharge", DoubleType(), True),
    StructField("total_amount", DoubleType(), True)])

# 2009 though 2014
yellowTripSchemaPre2015 = StructType([
    StructField("vendor_id", StringType(), True),
    StructField("pickup_datetime", TimestampType(), True),
    StructField("dropoff_datetime", TimestampType(), True),
    StructField("passenger_count", IntegerType(), True),
    StructField("trip_distance", DoubleType(), True),
    StructField("pickup_longitude", DoubleType(), True),
    StructField("pickup_latitude", DoubleType(), True),
    StructField("rate_code_id", IntegerType(), True),
    StructField("store_and_fwd_flag", StringType(), True),
    StructField("dropoff_longitude", DoubleType(), True),
    StructField("dropoff_latitude", DoubleType(), True),
    StructField("payment_type", StringType(), True),
    StructField("fare_amount", DoubleType(), True),
    StructField("extra", DoubleType(), True),
    StructField("mta_tax", DoubleType(), True),
    StructField("tip_amount", DoubleType(), True),
    StructField("tolls_amount", DoubleType(), True),
    StructField("total_amount", DoubleType(), True)])

# %% [markdown]
# #### 3. Some functions

# %%
#1) Function to determine schema for a given year and month
#Input:  Year and month
#Output: StructType for applicable schema 
#Sample call: print getSchemaStruct(2009,1)

def getTaxiSchema(tripYear, tripMonth):
  taxiSchema = None

  if(tripYear > 2008 and tripYear < 2015):
    taxiSchema = yellowTripSchemaPre2015
  elif(tripYear == 2016 and tripMonth > 6):
    taxiSchema = yellowTripSchema2016H2
  elif((tripYear == 2016 and tripMonth < 7) or (tripYear == 2015)):
    taxiSchema = yellowTripSchema20152016H1
  elif(tripYear == 2017 and tripMonth < 7):
    taxiSchema = yellowTripSchema2017H1
  
  return taxiSchema

# %%
#2) Function to add columns to dataframe as required to homogenize schema
#Input:  Dataframe, year and month
#Output: Dataframe with homogenized schema 
#Sample call: println(getSchemaHomogenizedDataframe(DF,2014,6))

from pyspark.sql.functions import *

def getSchemaHomogenizedDataframe(sourceDF,tripYear, tripMonth):
  if(tripYear > 2008 and tripYear < 2015):
    sourceDF = (sourceDF.withColumn("pickup_location_id", lit(0).cast("integer"))
              .withColumn("dropoff_location_id", lit(0).cast("integer"))
              .withColumn("improvement_surcharge",lit(0).cast("double"))
              .withColumn("junk1",lit(""))
              .withColumn("junk2",lit(""))
              .withColumn("trip_year",substring(col("pickup_datetime"),0, 4))
              .withColumn("trip_month",substring(col("pickup_datetime"),6,2))
              .withColumn("taxi_type",lit("yellow"))
              .withColumn("temp_pickup_longitude", col("pickup_longitude").cast("string"))
                                      .drop("pickup_longitude").withColumnRenamed("temp_pickup_longitude", "pickup_longitude")
              .withColumn("temp_dropoff_longitude", col("dropoff_longitude").cast("string"))
                                      .drop("dropoff_longitude").withColumnRenamed("temp_dropoff_longitude", "dropoff_longitude")
              .withColumn("temp_pickup_latitude", col("pickup_latitude").cast("string"))
                                      .drop("pickup_latitude").withColumnRenamed("temp_pickup_latitude", "pickup_latitude")
              .withColumn("temp_dropoff_latitude", col("dropoff_latitude").cast("string"))
                                      .drop("dropoff_latitude").withColumnRenamed("temp_dropoff_latitude", "dropoff_latitude")
              .withColumn("temp_payment_type", col("payment_type").cast("string")).drop("payment_type").withColumnRenamed("temp_payment_type", "payment_type"))
  elif((tripYear == 2016 and tripMonth < 7) or (tripYear == 2015)):
    sourceDF = (sourceDF.withColumn("pickup_location_id", lit(0).cast("integer"))
              .withColumn("dropoff_location_id", lit(0).cast("integer"))
              .withColumn("junk1",lit(""))
              .withColumn("junk2",lit(""))
              .withColumn("trip_year",substring(col("pickup_datetime"),0, 4))
              .withColumn("trip_month",substring(col("pickup_datetime"),6,2))
              .withColumn("taxi_type",lit("yellow"))
              .withColumn("temp_vendor_id", col("vendor_id").cast("string")).drop("vendor_id").withColumnRenamed("temp_vendor_id", "vendor_id")
              .withColumn("temp_pickup_longitude", col("pickup_longitude").cast("string"))
                                      .drop("pickup_longitude").withColumnRenamed("temp_pickup_longitude", "pickup_longitude")
              .withColumn("temp_dropoff_longitude", col("dropoff_longitude").cast("string"))
                                      .drop("dropoff_longitude").withColumnRenamed("temp_dropoff_longitude", "dropoff_longitude")
              .withColumn("temp_pickup_latitude", col("pickup_latitude").cast("string"))
                                      .drop("pickup_latitude").withColumnRenamed("temp_pickup_latitude", "pickup_latitude")
              .withColumn("temp_dropoff_latitude", col("dropoff_latitude").cast("string"))
                                      .drop("dropoff_latitude").withColumnRenamed("temp_dropoff_latitude", "dropoff_latitude")
              .withColumn("temp_payment_type", col("payment_type").cast("string")).drop("payment_type").withColumnRenamed("temp_payment_type", "payment_type"))
  elif(tripYear == 2016 and tripMonth > 6):
    sourceDF = (sourceDF.withColumn("pickup_longitude", lit(""))
              .withColumn("pickup_latitude", lit(""))
              .withColumn("dropoff_longitude", lit(""))
              .withColumn("dropoff_latitude", lit(""))
              .withColumn("trip_year",substring(col("pickup_datetime"),0, 4))
              .withColumn("trip_month",substring(col("pickup_datetime"),6,2))
              .withColumn("taxi_type",lit("yellow"))
              .withColumn("temp_vendor_id", col("vendor_id").cast("string")).drop("vendor_id").withColumnRenamed("temp_vendor_id", "vendor_id")
              .withColumn("temp_payment_type", col("payment_type").cast("string")).drop("payment_type").withColumnRenamed("temp_payment_type", "payment_type"))
  elif(tripYear == 2017 and tripMonth < 7):
    sourceDF = (sourceDF.withColumn("pickup_longitude", lit(""))
              .withColumn("pickup_latitude", lit(""))
              .withColumn("dropoff_longitude", lit(""))
              .withColumn("dropoff_latitude", lit(""))
              .withColumn("trip_year",substring(col("pickup_datetime"),0, 4))
              .withColumn("trip_month",substring(col("pickup_datetime"),6,2))
              .withColumn("taxi_type",lit("yellow"))
              .withColumn("junk1",lit(""))
              .withColumn("junk2",lit(""))
              .withColumn("temp_vendor_id", col("vendor_id").cast("string")).drop("vendor_id").withColumnRenamed("temp_vendor_id", "vendor_id")
              .withColumn("temp_payment_type", col("payment_type").cast("string")).drop("payment_type").withColumnRenamed("temp_payment_type", "payment_type"))
  else:
    sourceDF
    
  return sourceDF

# %% [markdown]
# #### 4. Read CSV, homogenize schema across years, save as parquet

# %%
# To make Hive Parquet format compatible with Spark Parquet format
spark.conf.set("spark.sql.parquet.writeLegacyFormat", "true")

# Disable delta optimizeWrite for consistent number of partition (when write from 2nd time, spark with delta format can reduce number of partitions)
spark.conf.set("spark.databricks.delta.optimizeWrite.enabled", "false")

spark.conf.set("spark.databricks.delta.properties.defaults.minReaderVersion", "3")

spark.conf.set("spark.databricks.delta.properties.defaults.minWriterVersion", "7")

#Process data, save as parquet
for j in range(2009,2018):
    
  endMonth = None
  if (j==2017):
    endMonth = 6 
  else: endMonth = 12
  
  for i in range(1,endMonth+1):
    
    srcDataFile= "{}year={}/month={:02d}/type=yellow/yellow_tripdata_{}-{:02d}.csv".format(srcDataDirRoot,j,i,j,i)
    print("Year={}; Month={}".format(j,i))
    print(srcDataFile)

    #Source schema
    taxiSchema = getTaxiSchema(j,i)

    #Read source data
    taxiDF = (spark.read.format("csv")
                    .option("header", True)
                    .schema(taxiSchema)
                    .option("delimiter",",")
                    .load(srcDataFile).cache())


    #Add additional columns to homogenize schema across years
    taxiFormattedDF = getSchemaHomogenizedDataframe(taxiDF, j, i)

    #Order all columns to align with the canonical schema for yellow taxi
    taxiCanonicalDF = taxiFormattedDF.select(*canonicalTripSchemaColList)
    
    year_month_dir = "{}trip_year={}/trip_month={:02d}".format(destDataDirRoot,j,i)
    dbutils.fs.rm(year_month_dir,recurse=True)

    taxiCanonicalDF.repartition(4).write.option("compression", "zstd").format("delta").mode("append").partitionBy("trip_year","trip_month").save(destDataDirRoot)
# Out:
# Year=2009; Month=1
# gs://nyctaxi-raw/transactional-data/year=2009/month=01/type=yellow/yellow_tripdata_2009-01.csv
# Year=2009; Month=2
# gs://nyctaxi-raw/transactional-data/year=2009/month=02/type=yellow/yellow_tripdata_2009-02.csv
# Year=2009; Month=3
# gs://nyctaxi-raw/transactional-data/year=2009/month=03/type=yellow/yellow_tripdata_2009-03.csv
# Year=2009; Month=4
# gs://nyctaxi-raw/transactional-data/year=2009/month=04/type=yellow/yellow_tripdata_2009-04.csv
# Year=2009; Month=5
# gs://nyctaxi-raw/transactional-data/year=2009/month=05/type=yellow/yellow_tripdata_2009-05.csv
# Year=2009; Month=6
# gs://nyctaxi-raw/transactional-data/year=2009/month=06/type=yellow/yellow_tripdata_2009-06.csv
# Year=2009; Month=7
# gs://nyctaxi-raw/transactional-data/year=2009/month=07/type=yellow/yellow_tripdata_2009-07.csv
# Year=2009; Month=8
# gs://nyctaxi-raw/transactional-data/year=2009/month=08/type=yellow/yellow_tripdata_2009-08.csv
# Year=2009; Month=9
# gs://nyctaxi-raw/transactional-data/year=2009/month=09/type=yellow/yellow_tripdata_2009-09.csv
# Year=2009; Month=10
# gs://nyctaxi-raw/transactional-data/year=2009/month=10/type=yellow/yellow_tripdata_2009-10.csv
# Year=2009; Month=11
# gs://nyctaxi-raw/transactional-data/year=2009/month=11/type=yellow/yellow_tripdata_2009-11.csv
# Year=2009; Month=12
# gs://nyctaxi-raw/transactional-data/year=2009/month=12/type=yellow/yellow_tripdata_2009-12.csv
# Year=2010; Month=1
# gs://nyctaxi-raw/transactional-data/year=2010/month=01/type=yellow/yellow_tripdata_2010-01.csv
# Year=2010; Month=2
# gs://nyctaxi-raw/transactional-data/year=2010/month=02/type=yellow/yellow_tripdata_2010-02.csv
# Year=2010; Month=3
# gs://nyctaxi-raw/transactional-data/year=2010/month=03/type=yellow/yellow_tripdata_2010-03.csv
# Year=2010; Month=4
# gs://nyctaxi-raw/transactional-data/year=2010/month=04/type=yellow/yellow_tripdata_2010-04.csv
# Year=2010; Month=5
# gs://nyctaxi-raw/transactional-data/year=2010/month=05/type=yellow/yellow_tripdata_2010-05.csv
# Year=2010; Month=6
# gs://nyctaxi-raw/transactional-data/year=2010/month=06/type=yellow/yellow_tripdata_2010-06.csv
# Year=2010; Month=7
# gs://nyctaxi-raw/transactional-data/year=2010/month=07/type=yellow/yellow_tripdata_2010-07.csv
# Year=2010; Month=8
# gs://nyctaxi-raw/transactional-data/year=2010/month=08/type=yellow/yellow_tripdata_2010-08.csv
# Year=2010; Month=9
# gs://nyctaxi-raw/transactional-data/year=2010/month=09/type=yellow/yellow_tripdata_2010-09.csv
# Year=2010; Month=10
# gs://nyctaxi-raw/transactional-data/year=2010/month=10/type=yellow/yellow_tripdata_2010-10.csv
# Year=2010; Month=11
# gs://nyctaxi-raw/transactional-data/year=2010/month=11/type=yellow/yellow_tripdata_2010-11.csv
# Year=2010; Month=12
# gs://nyctaxi-raw/transactional-data/year=2010/month=12/type=yellow/yellow_tripdata_2010-12.csv
# Year=2011; Month=1
# gs://nyctaxi-raw/transactional-data/year=2011/month=01/type=yellow/yellow_tripdata_2011-01.csv
# Year=2011; Month=2
# gs://nyctaxi-raw/transactional-data/year=2011/month=02/type=yellow/yellow_tripdata_2011-02.csv
# Year=2011; Month=3
# gs://nyctaxi-raw/transactional-data/year=2011/month=03/type=yellow/yellow_tripdata_2011-03.csv
# Year=2011; Month=4
# gs://nyctaxi-raw/transactional-data/year=2011/month=04/type=yellow/yellow_tripdata_2011-04.csv
# Year=2011; Month=5
# gs://nyctaxi-raw/transactional-data/year=2011/month=05/type=yellow/yellow_tripdata_2011-05.csv
# Year=2011; Month=6
# gs://nyctaxi-raw/transactional-data/year=2011/month=06/type=yellow/yellow_tripdata_2011-06.csv
# Year=2011; Month=7
# gs://nyctaxi-raw/transactional-data/year=2011/month=07/type=yellow/yellow_tripdata_2011-07.csv
# Year=2011; Month=8
# gs://nyctaxi-raw/transactional-data/year=2011/month=08/type=yellow/yellow_tripdata_2011-08.csv
# Year=2011; Month=9
# gs://nyctaxi-raw/transactional-data/year=2011/month=09/type=yellow/yellow_tripdata_2011-09.csv
# Year=2011; Month=10
# gs://nyctaxi-raw/transactional-data/year=2011/month=10/type=yellow/yellow_tripdata_2011-10.csv
# Year=2011; Month=11
# gs://nyctaxi-raw/transactional-data/year=2011/month=11/type=yellow/yellow_tripdata_2011-11.csv
# Year=2011; Month=12
# gs://nyctaxi-raw/transactional-data/year=2011/month=12/type=yellow/yellow_tripdata_2011-12.csv
# Year=2012; Month=1
# gs://nyctaxi-raw/transactional-data/year=2012/month=01/type=yellow/yellow_tripdata_2012-01.csv
# Year=2012; Month=2
# gs://nyctaxi-raw/transactional-data/year=2012/month=02/type=yellow/yellow_tripdata_2012-02.csv
# Year=2012; Month=3
# gs://nyctaxi-raw/transactional-data/year=2012/month=03/type=yellow/yellow_tripdata_2012-03.csv
# Year=2012; Month=4
# gs://nyctaxi-raw/transactional-data/year=2012/month=04/type=yellow/yellow_tripdata_2012-04.csv
# Year=2012; Month=5
# gs://nyctaxi-raw/transactional-data/year=2012/month=05/type=yellow/yellow_tripdata_2012-05.csv
# Year=2012; Month=6
# gs://nyctaxi-raw/transactional-data/year=2012/month=06/type=yellow/yellow_tripdata_2012-06.csv
# Year=2012; Month=7
# gs://nyctaxi-raw/transactional-data/year=2012/month=07/type=yellow/yellow_tripdata_2012-07.csv
# Year=2012; Month=8
# gs://nyctaxi-raw/transactional-data/year=2012/month=08/type=yellow/yellow_tripdata_2012-08.csv
# Year=2012; Month=9
# gs://nyctaxi-raw/transactional-data/year=2012/month=09/type=yellow/yellow_tripdata_2012-09.csv
# Year=2012; Month=10
# gs://nyctaxi-raw/transactional-data/year=2012/month=10/type=yellow/yellow_tripdata_2012-10.csv
# Year=2012; Month=11
# gs://nyctaxi-raw/transactional-data/year=2012/month=11/type=yellow/yellow_tripdata_2012-11.csv
# Year=2012; Month=12
# gs://nyctaxi-raw/transactional-data/year=2012/month=12/type=yellow/yellow_tripdata_2012-12.csv
# Year=2013; Month=1
# gs://nyctaxi-raw/transactional-data/year=2013/month=01/type=yellow/yellow_tripdata_2013-01.csv
# Year=2013; Month=2
# gs://nyctaxi-raw/transactional-data/year=2013/month=02/type=yellow/yellow_tripdata_2013-02.csv
# Year=2013; Month=3
# gs://nyctaxi-raw/transactional-data/year=2013/month=03/type=yellow/yellow_tripdata_2013-03.csv
# Year=2013; Month=4
# gs://nyctaxi-raw/transactional-data/year=2013/month=04/type=yellow/yellow_tripdata_2013-04.csv
# Year=2013; Month=5
# gs://nyctaxi-raw/transactional-data/year=2013/month=05/type=yellow/yellow_tripdata_2013-05.csv
# Year=2013; Month=6
# gs://nyctaxi-raw/transactional-data/year=2013/month=06/type=yellow/yellow_tripdata_2013-06.csv
# Year=2013; Month=7
# gs://nyctaxi-raw/transactional-data/year=2013/month=07/type=yellow/yellow_tripdata_2013-07.csv
# Year=2013; Month=8
# gs://nyctaxi-raw/transactional-data/year=2013/month=08/type=yellow/yellow_tripdata_2013-08.csv
# Year=2013; Month=9
# gs://nyctaxi-raw/transactional-data/year=2013/month=09/type=yellow/yellow_tripdata_2013-09.csv
# Year=2013; Month=10
# gs://nyctaxi-raw/transactional-data/year=2013/month=10/type=yellow/yellow_tripdata_2013-10.csv
# Year=2013; Month=11
# gs://nyctaxi-raw/transactional-data/year=2013/month=11/type=yellow/yellow_tripdata_2013-11.csv
# Year=2013; Month=12
# gs://nyctaxi-raw/transactional-data/year=2013/month=12/type=yellow/yellow_tripdata_2013-12.csv
# Year=2014; Month=1
# gs://nyctaxi-raw/transactional-data/year=2014/month=01/type=yellow/yellow_tripdata_2014-01.csv
# Year=2014; Month=2
# gs://nyctaxi-raw/transactional-data/year=2014/month=02/type=yellow/yellow_tripdata_2014-02.csv
# Year=2014; Month=3
# gs://nyctaxi-raw/transactional-data/year=2014/month=03/type=yellow/yellow_tripdata_2014-03.csv
# Year=2014; Month=4
# gs://nyctaxi-raw/transactional-data/year=2014/month=04/type=yellow/yellow_tripdata_2014-04.csv
# Year=2014; Month=5
# gs://nyctaxi-raw/transactional-data/year=2014/month=05/type=yellow/yellow_tripdata_2014-05.csv
# Year=2014; Month=6
# gs://nyctaxi-raw/transactional-data/year=2014/month=06/type=yellow/yellow_tripdata_2014-06.csv
# Year=2014; Month=7
# gs://nyctaxi-raw/transactional-data/year=2014/month=07/type=yellow/yellow_tripdata_2014-07.csv
# Year=2014; Month=8
# gs://nyctaxi-raw/transactional-data/year=2014/month=08/type=yellow/yellow_tripdata_2014-08.csv
# Year=2014; Month=9
# gs://nyctaxi-raw/transactional-data/year=2014/month=09/type=yellow/yellow_tripdata_2014-09.csv
# Year=2014; Month=10
# gs://nyctaxi-raw/transactional-data/year=2014/month=10/type=yellow/yellow_tripdata_2014-10.csv
# Year=2014; Month=11
# gs://nyctaxi-raw/transactional-data/year=2014/month=11/type=yellow/yellow_tripdata_2014-11.csv
# Year=2014; Month=12
# gs://nyctaxi-raw/transactional-data/year=2014/month=12/type=yellow/yellow_tripdata_2014-12.csv
# Year=2015; Month=1
# gs://nyctaxi-raw/transactional-data/year=2015/month=01/type=yellow/yellow_tripdata_2015-01.csv
# Year=2015; Month=2
# gs://nyctaxi-raw/transactional-data/year=2015/month=02/type=yellow/yellow_tripdata_2015-02.csv
# Year=2015; Month=3
# gs://nyctaxi-raw/transactional-data/year=2015/month=03/type=yellow/yellow_tripdata_2015-03.csv
# Year=2015; Month=4
# gs://nyctaxi-raw/transactional-data/year=2015/month=04/type=yellow/yellow_tripdata_2015-04.csv
# Year=2015; Month=5
# gs://nyctaxi-raw/transactional-data/year=2015/month=05/type=yellow/yellow_tripdata_2015-05.csv
# Year=2015; Month=6
# gs://nyctaxi-raw/transactional-data/year=2015/month=06/type=yellow/yellow_tripdata_2015-06.csv
# Year=2015; Month=7
# gs://nyctaxi-raw/transactional-data/year=2015/month=07/type=yellow/yellow_tripdata_2015-07.csv
# Year=2015; Month=8
# gs://nyctaxi-raw/transactional-data/year=2015/month=08/type=yellow/yellow_tripdata_2015-08.csv
# Year=2015; Month=9
# gs://nyctaxi-raw/transactional-data/year=2015/month=09/type=yellow/yellow_tripdata_2015-09.csv
# Year=2015; Month=10
# gs://nyctaxi-raw/transactional-data/year=2015/month=10/type=yellow/yellow_tripdata_2015-10.csv
# Year=2015; Month=11
# gs://nyctaxi-raw/transactional-data/year=2015/month=11/type=yellow/yellow_tripdata_2015-11.csv
# Year=2015; Month=12
# gs://nyctaxi-raw/transactional-data/year=2015/month=12/type=yellow/yellow_tripdata_2015-12.csv
# Year=2016; Month=1
# gs://nyctaxi-raw/transactional-data/year=2016/month=01/type=yellow/yellow_tripdata_2016-01.csv
# Year=2016; Month=2
# gs://nyctaxi-raw/transactional-data/year=2016/month=02/type=yellow/yellow_tripdata_2016-02.csv
# Year=2016; Month=3
# gs://nyctaxi-raw/transactional-data/year=2016/month=03/type=yellow/yellow_tripdata_2016-03.csv
# Year=2016; Month=4
# gs://nyctaxi-raw/transactional-data/year=2016/month=04/type=yellow/yellow_tripdata_2016-04.csv
# Year=2016; Month=5
# gs://nyctaxi-raw/transactional-data/year=2016/month=05/type=yellow/yellow_tripdata_2016-05.csv
# Year=2016; Month=6
# gs://nyctaxi-raw/transactional-data/year=2016/month=06/type=yellow/yellow_tripdata_2016-06.csv
# Year=2016; Month=7
# gs://nyctaxi-raw/transactional-data/year=2016/month=07/type=yellow/yellow_tripdata_2016-07.csv
# Year=2016; Month=8
# gs://nyctaxi-raw/transactional-data/year=2016/month=08/type=yellow/yellow_tripdata_2016-08.csv
# Year=2016; Month=9
# gs://nyctaxi-raw/transactional-data/year=2016/month=09/type=yellow/yellow_tripdata_2016-09.csv
# Year=2016; Month=10
# gs://nyctaxi-raw/transactional-data/year=2016/month=10/type=yellow/yellow_tripdata_2016-10.csv
# Year=2016; Month=11
# gs://nyctaxi-raw/transactional-data/year=2016/month=11/type=yellow/yellow_tripdata_2016-11.csv
# Year=2016; Month=12
# gs://nyctaxi-raw/transactional-data/year=2016/month=12/type=yellow/yellow_tripdata_2016-12.csv
# Year=2017; Month=1
# gs://nyctaxi-raw/transactional-data/year=2017/month=01/type=yellow/yellow_tripdata_2017-01.csv
# Year=2017; Month=2
# gs://nyctaxi-raw/transactional-data/year=2017/month=02/type=yellow/yellow_tripdata_2017-02.csv
# Year=2017; Month=3
# gs://nyctaxi-raw/transactional-data/year=2017/month=03/type=yellow/yellow_tripdata_2017-03.csv
# Year=2017; Month=4
# gs://nyctaxi-raw/transactional-data/year=2017/month=04/type=yellow/yellow_tripdata_2017-04.csv
# Year=2017; Month=5
# gs://nyctaxi-raw/transactional-data/year=2017/month=05/type=yellow/yellow_tripdata_2017-05.csv
# Year=2017; Month=6
# gs://nyctaxi-raw/transactional-data/year=2017/month=06/type=yellow/yellow_tripdata_2017-06.csv

# %%
def create_table(schema: str, table_name: str, parquet_dir: str, location: str):
    spark.sql(f"use {schema};")
    spark.sql(f"DROP TABLE IF EXISTS {table_name};")
    spark.sql(f"CREATE TABLE IF NOT EXISTS {table_name} USING delta LOCATION '{location}/{parquet_dir}';")

# %%
create_table(schema="synapse_nyc_reference.nyctaxi", table_name="yellow_taxi_trips_raw", parquet_dir="", location=destDataDirRoot)

# %%
# %sql
FSCK REPAIR TABLE nyctaxi.yellow_taxi_trips_raw;
# Out:
# <Empty result set>

# %% [markdown]
# #### 5. Statistics table

# %%
# %sql
select * from nyctaxi.yellow_taxi_trips_raw;
# Out:
# <div style="height:300px;overflow:auto;resize:both;"><table style="width:100%" class="searchable sortable"><thead><tr><th>taxi_type</th><th>vendor_id</th><th>pickup_datetime</th><th>dropoff_datetime</th><th>store_and_fwd_flag</th><th>rate_code_id</th><th>pickup_location_id</th><th>dropoff_location_id</th><th>pickup_longitude</th><th>pickup_latitude</th><th>dropoff_longitude</th><th>dropoff_latitude</th><th>passenger_count</th><th>trip_distance</th><th>fare_amount</th><th>extra</th><th>mta_tax</th><th>tip_amount</th><th>tolls_amount</th><th>improvement_surcharge</th><th>total_amount</th><th>payment_type</th><th>trip_year</th><th>trip_month</th></tr></thead><tbody><tr><td>yellow</td><td>CMT</td><td>2009-01-13T18:05:39Z</td><td>2009-01-13T18:05:56Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1</td><td>0</td><td>3.5</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>3.5</td><td>No Charge</td><td>2009</td><td>01</td></tr><tr><td>yellow</td><td>CMT</td><td>2009-01-09T15:41:39Z</td><td>2009-01-09T15:50:08Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>-73.987789</td><td>40.738054</td><td>-73.996866</td><td>40.747556</td><td>1</td><td>1.1</td><td>6.5</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>6.5</td><td>Cash</td><td>2009</td><td>01</td></tr><tr><td>yellow</td><td>VTS</td><td>2009-01-07T18:18:00Z</td><td>2009-01-07T18:28:00Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>-73.99966</td><td>40.718172</td><td>-73.981973</td><td>40.714512</td><td>2</td><td>1.08</td><td>6.9</td><td>1</td><td>null</td><td>0</td><td>0</td><td>0</td><td>7.9</td><td>CASH</td><td>2009</td><td>01</td></tr><tr><td>yellow</td><td>VTS</td><td>2009-01-02T13:47:00Z</td><td>2009-01-02T14:09:00Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>-73.87292</td><td>40.773947</td><td>-74.006068</td><td>40.706818</td><td>1</td><td>14.58</td><td>32.1</td><td>0</td><td>null</td><td>5</td><td>4.15</td><td>0</td><td>41.25</td><td>Credit</td><td>2009</td><td>01</td></tr><tr><td>yellow</td><td>VTS</td><td>2009-01-31T00:06:00Z</td><td>2009-01-31T00:30:00Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>-73.983933</td><td>40.766418</td><td>-73.974598</td><td>40.770735</td><td>3</td><td>3.94</td><td>16.1</td><td>0.5</td><td>null</td><td>1.5</td><td>0</td><td>0</td><td>18.1</td><td>Credit</td><td>2009</td><td>01</td></tr><tr><td>yellow</td><td>CMT</td><td>2009-01-03T21:55:48Z</td><td>2009-01-03T22:13:02Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>-73.976963</td><td>40.743106</td><td>-73.97389</td><td>40.783972</td><td>1</td><td>3.9</td><td>13.4</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>13.4</td><td>Cash</td><td>2009</td><td>01</td></tr><tr><td>yellow</td><td>CMT</td><td>2009-01-10T20:02:34Z</td><td>2009-01-10T20:06:36Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>-73.973516</td><td>40.74831</td><td>-73.988228</td><td>40.734625</td><td>1</td><td>1.4</td><td>5.3</td><td>0</td><td>null</td><td>0.79</td><td>0</td><td>0</td><td>6.09</td><td>Credit</td><td>2009</td><td>01</td></tr><tr><td>yellow</td><td>VTS</td><td>2009-01-13T07:40:00Z</td><td>2009-01-13T07:39:00Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>1</td><td>1.34</td><td>6.9</td><td>0</td><td>null</td><td>1.4</td><td>0</td><td>0</td><td>8.3</td><td>Credit</td><td>2009</td><td>01</td></tr><tr><td>yellow</td><td>DDS</td><td>2009-01-23T18:20:39Z</td><td>2009-01-23T18:31:24Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>-74.010084</td><td>40.711525</td><td>-73.994213</td><td>40.719848</td><td>1</td><td>1.1</td><td>6.5</td><td>1</td><td>null</td><td>0</td><td>0</td><td>0</td><td>7.5</td><td>CASH</td><td>2009</td><td>01</td></tr><tr><td>yellow</td><td>VTS</td><td>2009-01-30T11:11:00Z</td><td>2009-01-30T11:22:00Z</td><td>null</td><td>null</td><td>0</td><td>0</td><td>-73.97097</td><td>40.758097</td><td>-73.984092</td><td>40.76 ...

# %%
# %sql
select COUNT(1) from nyctaxi.yellow_taxi_trips_raw;
# Out:
# <div style="height:300px;overflow:auto;resize:both;"><table style="width:100%" class="searchable sortable"><thead><tr><th>count(1)</th></tr></thead><tbody><tr><td>1369889774</td></tr></tbody></table></div>
